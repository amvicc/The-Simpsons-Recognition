# %% [markdown]
# # Распознавание Симпсонов

# %% [markdown]
# ## Введение

# %% [markdown]
# ### Коротко о применении нейросетей
#
# Нейронные сети используются для решения сложных задач, которые требуют аналитических вычислений подобных тем, что делает человеческий мозг. Самыми распространенными применениями нейронных сетей является:
#
# Классификация — распределение данных по параметрам. Например, на вход дается набор людей и нужно решить, кому из них давать кредит, а кому нет. Эту работу может сделать нейронная сеть, анализируя такую информацию как: возраст, платежеспособность, кредитная история и тд.
#
# Предсказание — возможность предсказывать следующий шаг. Например, рост или падение акций, основываясь на ситуации на фондовом рынке.
#
# Распознавание — в настоящее время, самое широкое применение нейронных сетей. Используется в Google, когда вы ищете фото или в камерах телефонов, когда оно определяет положение вашего лица и выделяет его и многое другое.

# %% [markdown]
# ### Описание проекта
#
# В рамках практической работы по дисциплине "Социально-этические вопросы ИТ" наша команда решила создать нейросеть, целью которой будет распознавание персонажей из сериала "Симпсоны" (The Simpsons).
#
# Для обучения модели мы будем использовать датасет из 990 картинок, сгруппированных по папкам таким образом, что картинки с одним персонажем лежат в папке, название которой совпадает с именем этого персонажа.

# %% [markdown]
#  ![alt text](https://cdn1.thr.com/sites/default/files/imagecache/768x433/2018/09/simpsons_header-h_2018.jpg)
#
#
#
#
# ### Краткое описание проекта
#
#
# * Применяем набор аугментаций со случайным порядком и кастомизируемыми вероятностями для каждой из трансформаций
#
# * Маловероятно произвести надёжную валидацию при таком дисбалансе классов и малом количестве образцов, поэтому используем полностью все размеченные образцы для обучения модели. Это должно хоть немного повысить работоспособность классификации, в особенности для маленьких классов
#
# * Для сравнения степени влияния аугментации на целевые метрики создадим 2 датасета (один с аугментацией, другой - без)
#
# * Создадим нейронную сеть с большими дропаутами
#
# * Добавляем случайный шум к загруженным изображениям из train
#
# * Применяем weighted random sampler внутри data loader, чтобы бороться с дисбалансом классов
#
# * Размер батча должен быть кратным количеству классов (то есть: 42; 84; 126; 168 и т.п.)
#
# * Изменяем *batch size* и *learning rate* каждые 10 эпох
#
# * Периодически сохраняем промежуточные состояния весов модели (могут пригодиться, чтобы откатить обучение)
#
# *********************

# %% [markdown]
# # Импортируем библиотеки

# %%
import pandas as pd
import torch
import PIL
import pickle
import numpy as np
from skimage import io
import random

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %% [markdown]
# # Фиксируем параметры генераторов случайных чисел для воспроизводимости результатов

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

DEVICE = torch.device("cuda")

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# !unzip /content/gdrive/My\ Drive/Simpsons/simpsons4.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1026.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1027.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1028.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1029.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1030.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1031.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1032.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1033.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1034.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1035.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1036.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1037.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1038.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1039.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1040.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1041.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1042.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1043.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1044.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1045.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1046.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1047.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1048.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1049.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1050.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1051.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1052.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1053.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1054.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1055.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1056.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1057.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1058.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1059.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1060.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1061.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1062.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1063.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1064.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1065.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1066.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1067.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1068.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1069.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1070.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1071.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1072.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1073.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1074.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1075.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1076.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1077.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1078.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1079.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1080.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1081.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1082.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1083.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1084.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1085.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1086.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1087.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1088.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1089.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1090.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1091.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1092.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1093.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1094.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1095.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1096.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1097.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1098.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1099.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1100.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1101.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1102.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1103.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1104.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1105.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1106.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1107.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1108.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1109.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1110.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1111.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1112.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1113.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1114.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1115.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1116.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1117.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1118.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1119.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1120.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1121.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1122.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1123.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1124.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1125.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1126.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1127.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1128.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1129.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1130.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1131.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1132.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1133.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1134.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1135.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1136.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1137.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1138.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1139.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1140.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1141.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1142.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1143.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1144.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1145.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1146.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1147.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1148.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1149.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1150.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1151.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1152.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1153.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1154.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1155.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1156.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1157.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1158.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1159.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1160.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1161.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1162.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1163.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1164.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1165.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1166.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1167.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1168.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1169.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1170.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1171.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1172.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1173.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1174.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1175.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1176.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1177.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1178.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1179.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1180.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1181.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1182.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1183.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1184.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1185.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1186.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1187.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1188.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1189.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1190.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1191.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1192.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1193.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1194.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1195.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1196.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1197.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1198.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1199.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1200.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1201.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1202.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1203.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1204.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1205.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1206.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1207.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1208.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1209.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1210.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1211.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1212.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1213.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1214.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1215.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1216.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1217.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1218.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1219.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1220.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1221.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1222.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1223.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1224.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1225.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1226.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1227.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1228.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1229.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1230.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1231.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1232.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1233.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1234.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1235.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1236.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1237.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1238.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1239.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1240.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1241.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1242.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1243.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1244.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1245.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1246.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1247.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1248.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1249.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1250.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1251.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1252.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1253.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1254.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1255.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1256.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1257.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1258.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1259.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1260.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1261.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1262.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1263.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1264.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1265.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1266.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1267.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1268.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1269.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1270.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1271.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1272.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1273.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1274.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1275.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1276.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1277.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1278.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1279.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1280.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1281.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1282.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1283.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1284.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1285.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1286.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1287.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1288.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1289.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1290.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1291.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1292.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1293.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1294.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1295.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1296.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1297.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1298.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1299.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1300.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1301.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1302.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1303.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1304.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1305.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1306.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1307.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1308.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1309.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1310.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1311.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1312.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1313.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1314.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1315.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1316.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1317.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1318.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1319.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1320.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1321.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1322.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1323.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1324.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1325.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1326.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1327.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1328.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1329.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1330.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1331.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1332.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1333.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1334.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1335.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1336.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1337.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1338.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1339.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1340.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1341.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1342.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1343.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1344.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1345.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1346.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1347.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1348.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1349.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1350.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1351.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1352.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1353.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1354.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1355.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1356.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1357.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1358.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1359.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1360.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1361.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1362.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1363.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1364.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1365.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1366.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1367.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1368.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1369.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1370.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1371.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1372.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1373.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1374.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1375.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1376.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1377.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1378.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1379.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1380.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1381.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1382.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1383.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1384.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1385.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1386.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1387.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1388.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1389.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1390.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1391.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1392.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1393.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1394.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1395.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1396.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1397.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1398.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1399.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1400.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1401.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1402.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1403.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1404.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1405.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1406.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1407.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1408.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1409.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1410.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1411.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1412.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1413.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1414.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1415.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1416.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1417.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1418.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1419.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1420.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1421.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1422.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1423.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1424.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1425.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1426.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1427.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1428.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1429.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1430.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1431.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1432.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1433.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1434.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1435.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1436.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1437.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1438.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1439.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1440.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1441.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1442.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1443.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1444.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1445.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1446.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1447.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1448.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1449.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1450.jpg
#   inflating: train/simpsons_dataset/moe_szyslak/pic_1451.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0000.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0001.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0002.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0003.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0004.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0005.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0006.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0007.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0008.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0009.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0010.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0011.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0012.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0013.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0014.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0015.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0016.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0017.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0018.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0019.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0020.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0021.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0022.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0023.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0024.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0025.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0026.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0027.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0028.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0029.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0030.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0031.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0032.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0033.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0034.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0035.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0036.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0037.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0038.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0039.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0040.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0041.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0042.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0043.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0044.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0045.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0046.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0047.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0048.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0049.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0050.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0051.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0052.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0053.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0054.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0055.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0056.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0057.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0058.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0059.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0060.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0061.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0062.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0063.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0064.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0065.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0066.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0067.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0068.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0069.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0070.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0071.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0072.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0073.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0074.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0075.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0076.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0077.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0078.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0079.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0080.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0081.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0082.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0083.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0084.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0085.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0086.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0087.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0088.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0089.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0090.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0091.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0092.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0093.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0094.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0095.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0096.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0097.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0098.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0099.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0100.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0101.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0102.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0103.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0104.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0105.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0106.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0107.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0108.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0109.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0110.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0111.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0112.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0113.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0114.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0115.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0116.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0117.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0118.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0119.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0120.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0121.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0122.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0123.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0124.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0125.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0126.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0127.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0128.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0129.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0130.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0131.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0132.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0133.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0134.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0135.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0136.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0137.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0138.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0139.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0140.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0141.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0142.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0143.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0144.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0145.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0146.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0147.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0148.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0149.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0150.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0151.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0152.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0153.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0154.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0155.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0156.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0157.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0158.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0159.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0160.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0161.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0162.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0163.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0164.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0165.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0166.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0167.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0168.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0169.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0170.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0171.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0172.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0173.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0174.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0175.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0176.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0177.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0178.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0179.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0180.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0181.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0182.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0183.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0184.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0185.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0186.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0187.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0188.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0189.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0190.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0191.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0192.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0193.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0194.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0195.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0196.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0197.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0198.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0199.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0200.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0201.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0202.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0203.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0204.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0205.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0206.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0207.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0208.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0209.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0210.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0211.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0212.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0213.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0214.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0215.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0216.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0217.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0218.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0219.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0220.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0221.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0222.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0223.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0224.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0225.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0226.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0227.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0228.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0229.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0230.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0231.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0232.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0233.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0234.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0235.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0236.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0237.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0238.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0239.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0240.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0241.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0242.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0243.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0244.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0245.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0246.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0247.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0248.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0249.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0250.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0251.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0252.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0253.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0254.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0255.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0256.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0257.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0258.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0259.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0260.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0261.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0262.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0263.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0264.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0265.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0266.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0267.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0268.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0269.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0270.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0271.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0272.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0273.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0274.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0275.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0276.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0277.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0278.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0279.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0280.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0281.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0282.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0283.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0284.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0285.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0286.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0287.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0288.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0289.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0290.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0291.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0292.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0293.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0294.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0295.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0296.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0297.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0298.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0299.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0300.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0301.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0302.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0303.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0304.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0305.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0306.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0307.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0308.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0309.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0310.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0311.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0312.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0313.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0314.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0315.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0316.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0317.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0318.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0319.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0320.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0321.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0322.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0323.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0324.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0325.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0326.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0327.jpg
#   inflating: train/simpsons_dataset/ned_flanders/pic_0328.jpg
# ...
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0005.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0006.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0007.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0008.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0009.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0010.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0011.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0012.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0013.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0014.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0015.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0016.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0017.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0018.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0019.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0020.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0021.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0022.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0023.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0024.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0025.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0026.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0027.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0028.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0029.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0030.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0031.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0032.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0033.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0034.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0035.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0036.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0037.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0038.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0039.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0040.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0041.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0042.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0043.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0044.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0045.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0046.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0047.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0048.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0049.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0050.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0051.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0052.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0053.jpg
#   inflating: train/simpsons_dataset/snake_jailbird/pic_0054.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0000.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0001.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0002.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0003.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0004.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0005.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0006.jpg
#   inflating: train/simpsons_dataset/troy_mcclure/pic_0007.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0000.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0001.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0002.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0003.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0004.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0005.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0006.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0007.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0008.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0009.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0010.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0011.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0012.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0013.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0014.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0015.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0016.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0017.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0018.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0019.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0020.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0021.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0022.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0023.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0024.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0025.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0026.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0027.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0028.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0029.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0030.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0031.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0032.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0033.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0034.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0035.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0036.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0037.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0038.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0039.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0040.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0041.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0042.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0043.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0044.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0045.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0046.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0047.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0048.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0049.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0050.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0051.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0052.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0053.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0054.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0055.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0056.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0057.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0058.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0059.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0060.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0061.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0062.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0063.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0064.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0065.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0066.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0067.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0068.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0069.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0070.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0071.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0072.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0073.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0074.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0075.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0076.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0077.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0078.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0079.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0080.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0081.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0082.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0083.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0084.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0085.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0086.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0087.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0088.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0089.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0090.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0091.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0092.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0093.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0094.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0095.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0096.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0097.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0098.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0099.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0100.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0101.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0102.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0103.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0104.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0105.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0106.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0107.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0108.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0109.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0110.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0111.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0112.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0113.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0114.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0115.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0116.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0117.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0118.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0119.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0120.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0121.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0122.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0123.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0124.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0125.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0126.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0127.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0128.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0129.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0130.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0131.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0132.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0133.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0134.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0135.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0136.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0137.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0138.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0139.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0140.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0141.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0142.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0143.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0144.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0145.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0146.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0147.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0148.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0149.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0150.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0151.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0152.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0153.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0154.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0155.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0156.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0157.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0158.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0159.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0160.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0161.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0162.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0163.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0164.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0165.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0166.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0167.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0168.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0169.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0170.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0171.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0172.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0173.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0174.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0175.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0176.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0177.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0178.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0179.jpg
#   inflating: train/simpsons_dataset/waylon_smithers/pic_0180.jpg

# %% [markdown]
# # Задаём набор аугментаций со случайным порядком и вероятностями для каждой из трансформаций

# %%
custom_augmentations_01 = transforms.RandomOrder([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply([transforms.RandomRotation(degrees=10)], p=0.25),
    transforms.RandomApply([transforms.RandomResizedCrop(224, scale=(0.8, 1.25), ratio=(0.8, 1.25))], p=0.25),
    transforms.RandomApply([transforms.RandomAffine((-10,10), (0.1,0.1))], p=0.25),
    transforms.RandomPerspective(distortion_scale=0.1, p=0.25),
    transforms.RandomApply([transforms.ColorJitter(brightness=0.02,contrast=0.02,saturation=0.02,hue=(-0.02, 0.02))], p=0.01)
    ])

# %% [markdown]
# # Создаём класс для датасета

# %%
class SimpsonsDataset(Dataset):
  def __init__(self, files, mode, augmentations):
    super().__init__()
    self.files = files
    self.mode = mode
    self.augmentations = augmentations

    self.len_ = len(self.files)
    self.label_encoder = LabelEncoder()

    if self.mode != 'test':
      self.labels = [path.parent.name for path in self.files]
      self.label_encoder.fit(self.labels)

      with open('label_encoder.pkl', 'wb') as le_dump:
        pickle.dump(self.label_encoder, le_dump)

  def __len__(self):
    return self.len_

  def load_sample(self, file):
    image = Image.open(file)
    image.load()
    return image

  def __getitem__(self, index):
    transform = transforms.Compose([
      transforms.ToTensor(),
      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])                                
    ])

    x = self.load_sample(self.files[index])
    
    if self.mode=='aug':
            x = self.augmentations(x)
        
    x = self._prepare_sample(x)
    x = np.array(x / 255, dtype='float32')

    x = transform(x)
  
    if self.mode == 'test':
      return x
    else:
        
      label = self.labels[index]
      label_id = self.label_encoder.transform([label])
      y = label_id.item()
      return x, y

  def _prepare_sample(self, image):
    image = image.resize((224, 224))
    
    return np.array(image)

# %% [markdown]
# # Определяем пути к папкам

# %%
# Раскомментировать несколько нижеследующих строк, если запуск из google colab и/или в случае, если используется доступ из google drive

TRAIN_DIR = Path('/content/train/simpsons_dataset')
TEST_DIR = Path('/content/testset/testset')

#TRAIN_DIR = Path('/input/simpsons4/train')
#TEST_DIR = Path('/input/simpsons4/testset/testset')

train_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %% [markdown]
# # Использем все 100% доступных маркированных образцов для обучения модели
#
#
#
#
# Вряд ли возможно провести надежную валидацию с учетом такого классового дисбаланса и разреженности образцов. Поэтому используем полностью все размеченные образцы для обучения модели.
#
# Это должно повысить надежность модели, особенно для небольших классов
#
# для сравнения степени влияния аугментации на целевые метрики создадим 2 датасета (один с аугментацией (**aug**), другой - без ()**no_aug**)

# %%
from sklearn.utils import shuffle

train_labels = [path.parent.name for path in train_files]

aug_files = shuffle(train_files, random_state = 0)
no_aug_files = shuffle(train_files, random_state = 0)

aug_dataset = SimpsonsDataset(train_files, mode='aug', augmentations=custom_augmentations_01)
no_aug_dataset = SimpsonsDataset(no_aug_files, mode='no_aug', augmentations=None)

# %% [markdown]
# # Создадим нейронную сеть с большими дропаутами

# %%
class SimpleModel(nn.Module):
  
    def __init__(self, n_classes):
        super().__init__()

        self.c1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2),
            nn.Dropout2d(0.8),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)            
        )
        self.c2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2),
            nn.Dropout2d(0.8),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.c3 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),
            nn.Dropout2d(0.8),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.c4 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=5, stride=1, padding=2),
            nn.Dropout2d(0.8),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.c5 = nn.Sequential(
            nn.Conv2d(in_channels=96, out_channels=160, kernel_size=5, stride=1, padding=2),
            nn.Dropout2d(0.8),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.f1 = nn.Sequential(
            nn.Linear(7 * 7 * 160, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
        )
        self.f2 = nn.Sequential(
            nn.Linear(1024, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU()
        )        
        self.f3 = nn.Linear(1024, n_classes)

    def forward(self, x):
        x = self.c1(x)
        x = self.c2(x)
        x = self.c3(x)
        x = self.c4(x)
        x = self.c5(x)
        x = x.view(-1, 7 * 7 * 160)
        x = self.f1(x)
        x = self.f2(x)

        logits = self.f3(x)
        return logits

# %% [markdown]
# # Определяем функции: train(), fit_epoch(), eval_epoch()
#
#
# * Добавляем случайный шум к загруженным изображениям из *train*
#
# * применяем weighted random sampler внутри data loader, чтобы бороться с дисбалансом классов
# * изменяем *batch size* и *learning rate* каждые 10 эпох
#
#
#
#
#  ![alt text](https://cnet3.cbsistatic.com/img/C_76GS_9sar6cHjcZtrq8Eo1xFE=/1092x0/2015/05/06/9e6093ac-cac7-46d8-b502-2c52faffc2fb/thesimpsons.jpg)

# %%
def fit_aug_epoch(model, aug_loader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
  
    for inputs, labels in aug_loader:
        # добавление случайного шума
        inputs = inputs + torch.empty(*inputs.size()).normal_(0, 0.0001)
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        preds = torch.argmax(outputs, 1)
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_data += inputs.size(0)
              
    aug_loss = running_loss / processed_data
    aug_acc = running_corrects.cpu().numpy() / processed_data
    return aug_loss, aug_acc

 
def eval_no_aug_epoch(model, no_aug_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in no_aug_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    no_aug_loss = running_loss / processed_size
    no_aug_acc = running_corrects.double() / processed_size
    return no_aug_loss, no_aug_acc
  
def train(aug_files, no_aug_files, model, epochs, batch_size, learning_rate):
    
    y_aug = pd.Series(aug_dataset.labels)
    
    # считаем образцы в каждом классе
    class_sample_count = y_aug.value_counts().to_dict()
    samples_counts = np.array(list(map(class_sample_count.get, y_aug)))
    
    # рассчитываем веса для каждого класса
    samples_weight = 1./samples_counts
    samples_weight = torch.from_numpy(samples_weight)
    
    # создаём weighted random sampler и применяем его в train_loader
    sampler = torch.utils.data.WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), num_samples=len(y_aug))
    aug_loader = DataLoader(aug_dataset, batch_size=batch_size, shuffle=False, sampler=sampler)

    no_aug_loader = DataLoader(no_aug_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} aug_loss: {t_loss:0.4f} \
    no_aug_loss {v_loss:0.4f} aug_acc {t_acc:0.4f} no_aug_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
      
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        #scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size = 5, gamma = 0.5)
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            aug_loss, aug_acc = fit_aug_epoch(model, aug_loader, criterion, optimizer)
            print("loss", aug_loss)
            
            no_aug_loss, no_aug_acc = eval_no_aug_epoch(model, no_aug_loader, criterion)
            history.append((aug_loss, aug_acc, no_aug_loss, no_aug_acc))
            
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=aug_loss,\
                                           v_loss=no_aug_loss, t_acc=aug_acc, v_acc=no_aug_acc))
            #scheduler.step()
    return history

# %% [markdown]
# # Определяем функцию *predict()*

# %%
def predict(model, aug_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %% [markdown]
# # Начнём обучать модель и будем периодически сохранять веса модели:
#
# размер батча должен быть кратным количеству классов (то есть: 42; 84; 126; 168 и т.п.)

# %% [markdown]
# # Первые 10 эпох
# > epochs=10, batch_size=168, learning_rate=0.01

# %%
n_classes = len(np.unique(train_labels))
model = SimpleModel(n_classes).to(DEVICE)

# начнём обучение с 10 эпох: размер батча должен быть кратным количеству классов (то есть: 1*42=42; 2*42=84; 3*42=126; 4*42=168 и т.п.)
history = train(aug_dataset, no_aug_dataset, model=model, epochs=10, batch_size=168, learning_rate=0.01)

# сохраним веса модели после 10 эпох
torch.save(model.state_dict(), "Simple_Simpson_model_001_weights_01.pth")

# сделаем визуализацию
loss, acc, val_loss, val_acc = zip(*history)
plt.figure(figsize=(15, 9))
plt.plot(loss, label="aug_loss")
plt.plot(val_loss, label="no_aug_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# loss 4.097498580466737
# epoch:  10%|█         | 1/10 [08:20<1:15:00, 500.06s/it]
# Epoch 001 aug_loss: 4.0975     no_aug_loss 3.7258 aug_acc 0.0247 no_aug_acc 0.0262
# loss 3.65059496497297

# %% [markdown]
# # 20 эпох
# > epochs=10, batch_size=126, learning_rate=0.01

# %%
# продолжим обучение ещё 10 эпох: уменьшим размер батча и learning rate
history = train(aug_dataset, no_aug_dataset, model=model, epochs=10, batch_size=126, learning_rate=0.01)

# сохраним веса модели после 20 эпох
torch.save(model.state_dict(), "Simple_Simpson_model_001_weights_02.pth")

# делаем визуализацию
loss, acc, val_loss, val_acc = zip(*history)
plt.figure(figsize=(15, 9))
plt.plot(loss, label="aug_loss")
plt.plot(val_loss, label="no_aug_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # 30 эпох
# > epochs=10, batch_size=84, learning_rate=0.001

# %%
history = train(aug_dataset, no_aug_dataset, model=model, epochs=10, batch_size=84, learning_rate=0.001)

torch.save(model.state_dict(), "Simple_Simpson_model_001_weights_03.pth")

# делаем визуализацию
loss, acc, val_loss, val_acc = zip(*history)
plt.figure(figsize=(15, 9))
plt.plot(loss, label="aug_loss")
plt.plot(val_loss, label="no_aug_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # 40 эпох
# > epochs=10, batch_size=42, learning_rate=0.001

# %%
history = train(aug_dataset, no_aug_dataset, model=model, epochs=10, batch_size=42, learning_rate=0.001)

torch.save(model.state_dict(), "Simple_Simpson_model_001_weights_04.pth")

# делаем визуализацию
loss, acc, val_loss, val_acc = zip(*history)
plt.figure(figsize=(15, 9))
plt.plot(loss, label="aug_loss")
plt.plot(val_loss, label="no_aug_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # 50 эпох
# > epochs=10, batch_size=42, learning_rate=0.001

# %%
history = train(aug_dataset, no_aug_dataset, model=model, epochs=10, batch_size=42, learning_rate=0.001)

torch.save(model.state_dict(), "Simple_Simpson_model_001_weights_05.pth")

# делаем визуализацию
loss, acc, val_loss, val_acc = zip(*history)
plt.figure(figsize=(15, 9))
plt.plot(loss, label="aug_loss")
plt.plot(val_loss, label="no_aug_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # 60 эпох
# > epochs=10, batch_size=42, learning_rate=0.001

# %%
history = train(aug_dataset, no_aug_dataset, model=model, epochs=10, batch_size=42, learning_rate=0.0001)

torch.save(model.state_dict(), "Simple_Simpson_model_001_weights_06.pth")

# делаем визуализацию
loss, acc, val_loss, val_acc = zip(*history)
plt.figure(figsize=(15, 9))
plt.plot(loss, label="aug_loss")
plt.plot(val_loss, label="no_aug_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # Делаем предсказание на тестовом датасете и генерируем submission

# %%
label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

test_dataset = SimpsonsDataset(test_files, mode="test", augmentations=None)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=42)
probs = predict(model, test_loader)

preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]

submit = pd.DataFrame({'Id': test_filenames, 'Expected': preds})
submit.head()

submit.to_csv('submission.csv', index=False)

# %% [markdown]
#  ![alt text](https://i.guim.co.uk/img/media/88f6b98714035656cb18fb282507b60e82edb0d7/0_35_2560_1536/master/2560.jpg?width=1920&quality=85&auto=format&fit=max&s=f09a5ef4ac4c0e214594f65315390016)
